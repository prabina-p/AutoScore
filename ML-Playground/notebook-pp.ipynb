# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('data/submission_metadata.csv')
data
# Out:
#          Name Student ID            Email    Status  Submission ID  \
# 0  Andrew Pan     A10001  andrep24@uw.edu  Ungraded      231798102
#
#    Total Score  Max Points  Question 1 Score  Question 1 Weight  \
# 0          0.0         4.0               NaN                1.0
#
#    Question 1 Graded?  ... Question 3.1 Score Question 3.1 Weight  \
# 0               False  ...                NaN                 1.0
#
#    Question 3.1 Graded?                             Question 3.1 Response  \
# 0                 False  bbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb
#
#    Question 3.1 Submitted At Question 3.2 Score Question 3.2 Weight  \
# 0  2024-02-17 14:56:55 -0800                NaN                 1.0
#
#    Question 3.2 Graded?                              Question 3.2 Response  \
# 0                 False  cccccccccccccccccccccccccccccccccccccccccccccc...
#
#    Question 3.2 Submitted At
# 0  2024-02-17 14:57:02 -0800
#
# [1 rows x 27 columns]

# %%
data = pd.read_csv('data/test3.csv')
data
# Out:
#                Name  ID                                Question 1 Response
# 0      Ethan Miller   0  A binary search tree (BST) is a data structure...
# 1                仁陈   1  A binary search tree is a tree data structure ...
# 2     Evelyn Slater   2  A binary search tree (BST) is a data structure...
# 3       Logan Hayes   3  Certainly, I can help you understand binary se...
# 4    Elisha Hawkins   4  A binary search tree (BST) is a data structure...
# 5   Kristina Cannon   5  A binary search tree (BST) is a data structure...
# 6   Sophia Anderson   6  A binary search tree is a data structure that ...
# 7       Kane Garcia   7  A binary search tree (BST) is a data structure...
# 8      Emma Hendrez   8  A binary search tree (BST) is a data structure...
# 9       Kale Klates   9  In a BST, each node has a value and two child ...
# 10       Kool Kloud  10  A binary search tree is like a special kind of...
# ...

# %%
prof_ans = '''
A binary search tree (BST) is a binary-tree based data structure that offers O(log n) average-case time costs for Add, Find, Remove, and findLargest/removeLargest element.
'''
